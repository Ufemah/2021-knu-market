# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
# %matplotlib inline

# %%
data_h = pd.read_csv('data/[1h]BTCUSDT.csv')
print(data1.head())
# Out:
#            Start           Stop     Open    Close      Low     High     Volume
# 0  1502942400000  1502945999999  4261.48  4308.83  4261.32  4313.62  47.181009
# 1  1502946000000  1502949599999  4308.83  4315.32  4291.37  4328.69  23.234916
# 2  1502949600000  1502953199999  4330.29  4324.35  4309.37  4345.45   7.229691
# 3  1502953200000  1502956799999  4316.62  4349.99  4287.41  4349.99   4.443249
# 4  1502956800000  1502960399999  4333.32  4360.69  4333.32  4377.85   0.972807

# %%
plt.figure(figsize=(15,10))
plt.plot(data_h.Volume)

# %%
#AR
model = AutoReg(data_h.Volume, lags=2,old_names = False)
yhat1 = model.fit().predict(0, len(data_h.Volume)+100)

# %%
plt.figure(figsize=(15,10))
plt.plot(data_h.Volume)
plt.plot(y1, 'red')

# %%
#MA
model = ARIMA(data_h.Volume, order=(0, 0, 1))
yhat2 = model.fit().predict(0, len(data_h.Volume) + 100)

# %%
plt.figure(figsize=(15,10))
plt.plot(range(len(yhat2)), yhat2, c='red', label='Pred')
plt.plot(range(len(data_h.Volume)), data_h.Volume, c='blue', label='Groundtruth')
plt.show()

# %%
#SES
model = SimpleExpSmoothing(data_h.Volume, initialization_method=None)
yhat3 = model.fit().predict(0, len(data_h.Volume)+100)

# %%
plt.figure(figsize=(15,10))
plt.plot(data_h.Volume)
plt.plot(yhat3, 'red')

# %%
#HWES
model = ExponentialSmoothing(data_h.Volume)
yhat4 = model.fit().predict(0, len(data_h.Volume)+100)

# %%
plt.figure(figsize=(15,10))
plt.plot(data_h.Volume)
plt.plot(yhat4, 'red')
