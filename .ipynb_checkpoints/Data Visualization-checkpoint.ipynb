# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # datasetH

# %%
datasetH = pd.read_csv("./data/[1h]BTCUSDT.csv")

# %%
datasetH
# Out:
#                Start           Stop      Open     Close       Low      High  \
# 0      1502942400000  1502945999999   4261.48   4308.83   4261.32   4313.62
# 1      1502946000000  1502949599999   4308.83   4315.32   4291.37   4328.69
# 2      1502949600000  1502953199999   4330.29   4324.35   4309.37   4345.45
# 3      1502953200000  1502956799999   4316.62   4349.99   4287.41   4349.99
# 4      1502956800000  1502960399999   4333.32   4360.69   4333.32   4377.85
# ...              ...            ...       ...       ...       ...       ...
# 29471  1609444800000  1609448399999  28897.84  29126.70  28862.00  29139.65
# 29472  1609448400000  1609451999999  29126.71  28966.36  28900.79  29169.55
# 29473  1609452000000  1609455599999  28966.36  29100.84  28910.19  29143.73
# 29474  1609455600000  1609459199999  29100.83  28923.63  28780.00  29110.35
# 29475  1609459200000  1609462799999  28923.63  28995.13  28690.17  29031.34
#
#             Volume
# 0        47.181009
# ...

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Start'], datasetH['Open'], color = 'red')
plt.title("Open price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Open price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Stop'], datasetH['Close'], color = 'red')
plt.title("Close price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Close price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Start'], datasetH['Open'], c='red', label="open price")
plt.plot(datasetH['Stop'], datasetH['Close'], c='black', label="cloce price")
plt.title("Open and Close price", fontsize=10)
plt.legend()

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Start'], datasetH['Low'], color = 'blue')
plt.title("Low price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Low price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Start'], datasetH['High'], color = 'red')
plt.title("High price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Start'], datasetH['Low'], color = 'blue', label='low price')
plt.plot(datasetH['Start'], datasetH['High'], color = 'red', label='high price')
plt.title("High and Low price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High and Low price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['Start'], datasetH['Volume'], color = 'gray')
plt.title("Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetH['High'] - datasetH['Low'], 'yellow')
plt.title("High price - Low price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High price - Low price')

# %%
plt.figure(figsize=(20, 5))
plt.plot((datasetH['Start'] + datasetH['Stop']) / 2, datasetH['Volume'], 'gray', datasetH['Start'], datasetH['Open'], 'black')
plt.title("Open price and Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Open price and Volume')

# %%
plt.figure(figsize=(20, 5))
plt.hist(datasetH['Volume'])
plt.title("Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
plt.figure(figsize=(20, 5))
sns.histplot(datasetH, x="Volume")
plt.title("Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
plt.figure(figsize=(20, 5))
plt.plot((datasetH['High'] - datasetH['Low']), datasetH['Volume'], 'red', linestyle="",marker="o", alpha=0.1)
plt.title("High price - Low Price by Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High price - Low Price by Volume')

# %% [markdown]
# # datasetM

# %%
datasetM = pd.read_csv("./data/[1m]BTCUSDT.csv")

# %%
datasetM
# Out:
#                  Start           Stop      Open     Close       Low      High  \
# 0        1502942400000  1502942459999   4261.48   4261.48   4261.48   4261.48
# 1        1502942460000  1502942519999   4261.48   4261.48   4261.48   4261.48
# 2        1502942520000  1502942579999   4280.56   4280.56   4280.56   4280.56
# 3        1502942580000  1502942639999   4261.48   4261.48   4261.48   4261.48
# 4        1502942640000  1502942699999   4261.48   4261.48   4261.48   4261.48
# ...                ...            ...       ...       ...       ...       ...
# 1767788  1609458960000  1609459019999  28978.91  28975.06  28969.99  28988.06
# 1767789  1609459020000  1609459079999  28975.06  28975.03  28955.35  28981.41
# 1767790  1609459080000  1609459139999  28975.03  28923.67  28923.15  28977.10
# 1767791  1609459140000  1609459199999  28923.66  28923.63  28903.86  28952.28
# 1767792  1609459200000  1609459259999  28923.63  28961.66  28913.12  28961.66
#
#             Volume
# ...

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Start'], datasetM['Open'], color = 'red')
plt.title("Open price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Open price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Stop'], datasetM['Close'], color = 'red')
plt.title("Close price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Close price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Start'], datasetM['Open'], c='red', label="open price")
plt.plot(datasetM['Stop'], datasetM['Close'], c='black', label="cloce price")
plt.title("Open and Close price", fontsize=10)
plt.legend()

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Start'], datasetM['Low'], color = 'blue')
plt.title("Low price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Low price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Start'], datasetM['High'], color = 'red')
plt.title("High price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High price')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Start'], datasetM['Low'], color = 'blue', label='low price')
plt.plot(datasetM['Start'], datasetM['High'], color = 'red', label='high price')
plt.title("High and Low price", fontsize=10)
plt.legend()

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['Start'], datasetM['Volume'], color = 'gray')
plt.title("Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
plt.figure(figsize=(20, 5))
plt.plot(datasetM['High'] - datasetM['Low'], 'yellow')
plt.title("High price - Low price", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High price - Low price')

# %%
plt.figure(figsize=(20, 5))
plt.plot((datasetM['Start'] + datasetM['Stop']) / 2 , datasetM['Volume'], 'gray', datasetM['Start'], datasetM['Open'], 'black', )
plt.title("Open price and Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Open price and Volume')

# %%
plt.figure(figsize=(20, 5))
plt.hist(datasetM['Volume'])
plt.title("Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
plt.figure(figsize=(20, 5))
sns.histplot(datasetM, x="Volume")
plt.title("Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Volume')

# %%
plt.figure(figsize=(20, 5))
plt.plot((datasetM['High'] - datasetM['Low']), datasetM['Volume'], 'red', linestyle="",marker="o", alpha=0.1)
plt.title("High price - Low Price by Volume", fontsize=10)
# Out:
# Text(0.5, 1.0, 'High price - Low Price by Volume')
